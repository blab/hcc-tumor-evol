# %% [markdown]
# # Visualizing BEAST  MCC Tree Using BALTIC

# %% [markdown]
# Maximum clade credability tree was dervied from BEAST output using Tree Annotator. BEAST was run using Yule speciation process and strict molecular clock. Location was input as a continuous bivariate trait that represented latitude and longitude and was modeled with gamma RRW. Both the location and clone was infered for all ancestors.

# %%
import baltic as bt ## In working directory OR add the path to baltic.py to your $PYTHONPATH environment variable
import copy
import numpy as np
import operator

# %% [markdown]
# ## Rooted tree w/ location as continuous bivariate trait

# %%
from matplotlib import pyplot as plt
import matplotlib as mpl
import matplotlib.lines as mlines
# %matplotlib inline 
## Magic words for jupyter notebooks

# %%
colors2 = {'beta':'lightgreen','gamma': 'gold', 'alpha': 'darkturquoise', 'epsilon':'salmon', 'zeta': 'orange', 'eta':'magenta','delta':
          'deepskyblue','mu':'green','omega':'k'}

# %% [markdown]
# ## Rooted tree w/ continuous bivariate space and inferred clone traits

# %%
tree2 = bt.loadNexus('alleles_spatial_clone_55.mcc', absoluteTime=False) #tree with locations + clones as infered traits

# %%
tree2 = bt.loadNexus('alleles_spatial_clone_55.mcc', absoluteTime=False) #tree with locations + clones as infered traits
fig1,ax = plt.subplots(figsize=(10,20),facecolor='w')
#ax = fig.add_subplot(3, 1, 1)

branchWidth=2 ## default branch width

cmap=mpl.cm.viridis ## colors! https://github.com/blab/wiki/wiki/Colors

for k in tree2.Objects: ## iterate over objects in tree
    x=k.x ## or from x position determined earlier
#     x=k.absoluteTime ## or use absolute time instead
    y=k.y ## get y position from .drawTree that was run earlier, but could be anything else
    
    xp=k.parent.x ## get x position of current object's parent
#     xp=k.parent.absoluteTime ## get x position of current object's parent
    if x==None: ## matplotlib won't plot Nones, like root
        x=0.0
    if xp==None:
        xp=x
    #if (isinstance(k, bt.leaf) or k.branchType=='leaf') and len(k.name.split('|')) > 1:
    #if isinstance(k, bt.leaf) and len(k.name.split('|')) > 1:
        #c = colors[k.name.split('|')[-3]]
    #else:
        #c='dimgray' ## colour can be fixed
    if k.traits['clone'] != 'nan':
        c = colors2[k.traits['clone']] if k.traits.has_key('clone') else cmap(1.0)[0]
    else: c = 'silver'
#     c=cmap(k.height/ll.treeHeight) ## or be a function of something else
#     c=[cmap(k.traits['host.prob']) if k.traits.has_key('host.prob') else cmap(1.0)][0]
#     c=['indianred' if k.traits['PB1']=='V' else 'steelblue'][0] ## can be discrete too
    
    if isinstance(k,bt.leaf) or k.branchType=='leaf': ## if leaf...
        #x=decimalDate(k.name.split('_')[-1],variable=True) ## get x position from name
        
        s=30 ## tip size can be fixed
        #s=50-30*k.height/tree2.treeHeight
        
        ax.scatter(x,y,s=s,facecolor=c,edgecolor='none',zorder=11) ## plot circle for every tip
        ax.scatter(x,y,s=s+0.8*s,facecolor='k',edgecolor='none',zorder=10) ## plot black circle underneath
    elif isinstance(k,bt.node) or k.branchType=='node': ## if node...
        #ax.plot([x,x],[k.children[-1].y,k.children[0].y],lw=branchWidth,color=c,ls='-',zorder=9)
        ax.plot([x,x],[k.children[-1].y,k.children[0].y],lw=branchWidth, color= c ,ls='-',zorder=9)
        
    #ax.plot([xp,x],[y,y],lw=branchWidth,color=c,ls='-',zorder=9)
    ax.plot([xp,x],[y,y],lw=branchWidth,color= c ,ls='-',zorder=9)
    
       
ax.set_ylim(-5,tree2.ySpan+5)
han_list = []

for key in colors2:
    marker = mlines.Line2D(range(1), range(1), color = colors2[key], marker='o', markerfacecolor = colors2[key], label = key, markeredgecolor='k',markersize = 8)
    han_list.append(marker)

plt.legend(handles = han_list,markerfirst = True,title = 'Clone')
plt.savefig('figures/rootedTree.png')
plt.show()

# %% [markdown]
# ## .... Unrooted tree

# %%
tree2 = bt.loadNexus('alleles_spatial_clone_55.mcc', absoluteTime=False) #tree with locations + clones as infered traits
tree2.uncollapseSubtree() ## uncollapse
tree2.drawUnrooted() ## draw tree as unrooted
fig,ax = plt.subplots(figsize=(10,10),facecolor='w')


for k in tree2.Objects: ## iterate over objects in tree
    x=k.x ## or from x position determined earlier
    y=k.y ## get y position from .drawTree that was run earlier, but could be anything else
    
    xp=k.parent.x ## get x position of current object's parent
    yp=k.parent.y
    
    if x==None: ## matplotlib won't plot Nones, like root
        x=0.0
    if xp==None:
        xp=x

    if k.traits['clone'] != 'nan':
        c = colors2[k.traits['clone']] if k.traits.has_key('clone') else cmap(1.0)[0]
    else: c = 'silver' 
    #cmap=[mpl.cm.Reds if k.traits['type']=='HongKong' else mpl.cm.Blues][0] ## pick colour map based on trait
    #c=cmap(k.height/mtt.treeHeight) ## colour with colour map based on height of branch
    if k.branchType=='leaf': ## if leaf...
        #s=30 ## tip size can be fixed
        s=30*k.height/tree2.treeHeight

        ax.scatter(x,y,s=s,facecolor=c,edgecolor='none',zorder=11) ## plot circle for every tip
        ax.scatter(x,y,s=s*2,facecolor='k',edgecolor='none',zorder=10) ## plot black circle underneath
    
    ax.plot([xp,x],[yp,y],lw=branchWidth,color=c,ls='-',zorder=9)

ax.spines['top'].set_visible(False) ## no axes
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

ax.tick_params(axis='x',size=0) ## no labels
ax.tick_params(axis='y',size=0)
ax.set_xticklabels([])
ax.set_yticklabels([])
plt.savefig('figures/unrootedTree.png')

# %% [markdown]
# ## .... Continuous space (x,y)

# %%
tree2 = bt.loadNexus('alleles_spatial_clone_55.mcc', absoluteTime=False) #tree with locations + clones as infered trait
colors3 = {'beta':'lightgreen','gamma': 'gold', 'alpha': 'darkturquoise', 'epsilon':'salmon', 'zeta': 'orange', 'eta':'magenta','delta':
          'deepskyblue','mu':'green'}
fig,ax = plt.subplots(figsize=(10,10),facecolor='w')

for k in tree2.Objects: ## iterate over objects in tree

    x = k.traits['location1']
    y = k.traits['location2']
    if  k.parent.traits.has_key('location1'):
        xp = k.parent.traits['location1']
    else:
        xp  = x
    if  k.parent.traits.has_key('location2'):
        yp = k.parent.traits['location2']
    else:
        yp = y
    
    if x==None: ## matplotlib won't plot Nones, like root
        x=0.0
    if xp==None:
        xp=x
    if k.traits['clone'] != 'omega':
        
        if k.traits['clone'] != 'nan':
            c = colors3[k.traits['clone']] if k.traits.has_key('clone') else cmap(1.0)[0]
        else: c = 'silver' 

        if k.branchType=='leaf': ## if leaf...
            s=45 ## tip size can be fixed
        
            ax.scatter(x,y,s=s,facecolor=c,edgecolor='none',zorder=11) ## plot circle for every tip
            ax.scatter(x,y,s=s*2,facecolor='k',edgecolor='none',zorder=10) ## plot black circle underneath
            
        ax.plot([xp,x],[yp,y],lw=branchWidth,color=c,ls='-',zorder=9)

#ax.spines['top'].set_visible(False) ## no axes
#ax.spines['right'].set_visible(False)
#ax.spines['left'].set_visible(False)
#ax.spines['bottom'].set_visible(False)

#ax.tick_params(axis='x',size=0) ## no labels
#ax.tick_params(axis='y',size=0)
#ax.set_xticklabels([])
#ax.set_yticklabels([])
han_list = []

for key in colors3:
    marker = mlines.Line2D(range(1), range(1), color = colors3[key], marker='o', markerfacecolor = colors3[key], label = key, markeredgecolor='k',markersize = 8)
    han_list.append(marker)

plt.legend(handles = han_list,markerfirst = True,title = 'Clone')

plt.savefig('figures/2dspaceTree.png')
plt.show()

# %% [markdown]
# ## .... Continuous space (x,y) w/  evolutionary distance (z)

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
tree2 = bt.loadNexus('alleles_spatial_clone_55.mcc', absoluteTime=False) #tree with locations + clones as infered trait

fig = plt.figure(figsize=(16,16))
ax = fig.add_subplot(111, projection='3d')

branchWidth=2 ## default branch width

for k in tree2.Objects: ## iterate over objects in tree
    
    x = k.traits['location1']
    y = k.traits['location2']
    if  k.parent.traits.has_key('location1'):
        xp = k.parent.traits['location1']
    else:
        xp  = x
    if  k.parent.traits.has_key('location2'):
        yp = k.parent.traits['location2']
    else:
        yp = y
    
    if x==None: ## matplotlib won't plot Nones, like root
        x=0.0
    if xp==None:
        xp=x
    z = k.x
    zp = k.parent.x
    if z == None:
        z = 0.0
    if zp == None:
        zp = z
    if k.traits['clone'] != 'omega':
        if k.traits['clone'] != 'nan':
            c = colors3[k.traits['clone']] if k.traits.has_key('clone') else cmap(1.0)[0]
        else: c = 'silver'
    
        if isinstance(k,bt.leaf) or k.branchType=='leaf': ## if leaf...e
        
            s = 50
            ax.scatter(x, y, z, zdir='z', s=s, c=c, depthshade=True,zorder = 10,edgecolor = 'k')
    
        ax.plot([xp,x],[yp,y],[zp,z],lw=branchWidth,color=c,ls='-',zorder=9)
        

han_list = []

for key in colors3:
    marker = mlines.Line2D(range(1), range(1), color = colors3[key], marker='o', markerfacecolor = colors3[key], label = key, markeredgecolor='k',markersize = 8)
    han_list.append(marker)

plt.legend(handles = han_list,markerfirst = True,title = 'Clone')
ax.set_xlabel('X coordinate (mm)')
ax.set_ylabel('Y coordiante (mm)')
ax.set_zticks([])


plt.savefig('figures/3dspaceTree.png')
plt.show()

# %% [markdown]
# ## Make function to slice single tree accross one time

# %%
def timeslice(tree, time): ## function to slice tree at time time
    newleaves = []
    for k in tree.Objects: ## loop through all nodes and leaves of tree
        g = k.traits['clone'] # store clone value
        if k.x <= time and k.traits['clone'] != 'omega':
            lx = k.traits['location1']
            ly = k.traits['location2']
            if isinstance(k,bt.leaf) or k.x == time: 
                if  k.parent.traits.has_key('location1'):
                    pxcoord = k.parent.traits['location1']
                else:
                    pxcoord  = lx
                if  k.parent.traits.has_key('location2'):
                    pycoord = k.parent.traits['location2']
                else:
                    pycoord = ly
                nl = {'xcoord':lx,'ycoord':ly,'clone':g,'pxcoord':pxcoord,'pycoord':pycoord, 'px': k.parent.x,"x":time}
                newleaves.append(nl)
            elif isinstance(k,bt.node) or k.branchType=='node':
                for c in k.children:
                    if c.x > time: 
                        lcx = c.traits['location1']
                        lcy = c.traits['location2']
                        m = (lcy - ly)/(lcx - lx)
                        deltaX = (time - k.x)/(c.x - k.x) * (lcx - lx)
                        newX = lx + deltaX
                        newY = ly + deltaX * m
                        nl = {'xcoord':newX,'ycoord':newY,'clone':g,'pxcoord':lx,'pycoord':ly, 'px': k.x, "x": time}
                        newleaves.append(nl)
    return newleaves

# %%
tree2 = bt.loadNexus('alleles_spatial_clone_55.mcc', absoluteTime=False) #tree with locations + clones as infered trait
times = [tree2.treeHeight * x / 4 for x in range(1,5)]
timep = ['25%', '50%', '75%','100%']

# %%
tree2 = bt.loadNexus('alleles_spatial_clone_55.mcc', absoluteTime=False) #tree with locations + clones as infered trait
times = [tree2.treeHeight * x / 4 for x in range(1,5)]
colors3 = {'beta':'lightgreen','gamma': 'gold', 'alpha': 'darkturquoise', 'epsilon':'salmon', 'zeta': 'orange', 'eta':'magenta','delta':
          'deepskyblue','mu':'green'}
branchWidth = 2
a = 0
fig,ax = plt.subplots(2,2,figsize=(15,15),sharex='col', sharey='row')


for i in [0,1]:
    for j in [0,1]:
        time = times[a]
        newleaves = timeslice(tree2,time)
        nodslice = []
        for k in tree2.Objects: ## iterate over objects in tree
            if k.x < time and k.traits['clone'] != 'omega':

                g = k.traits['clone']
                x = k.traits['location1']
                y = k.traits['location2']
                if  k.parent.traits.has_key('location1'):
                    xp = k.parent.traits['location1']
                else:
                    xp  = x
                if  k.parent.traits.has_key('location2'):
                    yp = k.parent.traits['location2']
                else:
                    yp = y

                if x==None: ## matplotlib won't plot Nones, like root
                    x=0.0
                if xp==None:
                    xp=x

                if k.traits['clone'] != 'nan':
                    if k.traits.has_key('clone'):
                        c = colors3[k.traits['clone']]
                    else: 
                        c = 'silver' 

                nn = {'xcoord':x,'ycoord':y,'clone':g,'pxcoord':xp,'pycoord':yp, 'px': k.parent.x,"x":k.x} 
                nodslice.append(nn)

                ax[i,j].plot([xp,x],[yp,y],lw=branchWidth,color=c,ls='-',zorder=9)


        for leaf in newleaves:
            if leaf['x'] == time:
                s = 45
                x = leaf['xcoord']
                y = leaf['ycoord']
                xp = leaf['pxcoord']
                yp = leaf['pycoord']
                if leaf['clone'] != 'omega':
                    if leaf['clone'] != 'nan' and leaf.has_key('clone'):
                        c = colors3[leaf['clone']]
                    else: 
                        c = 'silver'


                    ax[i,j].scatter(x,y,s=s,facecolor = c, edgecolor = 'k',zorder = 10)
                    ax[i,j].plot([xp,x],[yp,y], lw=branchWidth,color = c, ls='-',zorder = 9)
  
        ax[1,j].set_xlabel('X coordinate (mm)')
        ax[i,0].set_ylabel('Y coordiante (mm)')
        ax[i,j].set_xlim(-17,17)
        ax[i,j].set_ylim(-17,17)
        ax[i,j].set_title('%s of Total Distance' % timep[a])
        a += 1
han_list = []

for key in colors3:
    marker = mlines.Line2D(range(1), range(1), color = colors3[key], marker='o', markerfacecolor = colors3[key], label = key, markeredgecolor='k',markersize = 8)
    han_list.append(marker)

ax[1,1].legend(handles = han_list, markerfirst = True, title = 'Clone', bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.savefig('figures/2dspace_timeslice.png')

plt.show()

# %%
tree2 = bt.loadNexus('alleles_spatial_clone_55.mcc', absoluteTime=False) #tree with locations + clones as infered trait
times = [tree2.treeHeight * x / 4 for x in range(1,5)]
colors3 = {'beta':'lightgreen','gamma': 'gold', 'alpha': 'darkturquoise', 'epsilon':'salmon', 'zeta': 'orange', 'eta':'magenta','delta':
          'deepskyblue','mu':'green'}
branchWidth = 2
a = 1

fig = plt.figure(figsize=(15,15))
#ax = fig.add_subplot(221, projection='3d')
#fig,ax = plt.subplots(2,2, projection='3d',figsize=(15,15), sharex='col', sharey='row')


for i in [0,1]:
    for j in [0,1]:
        time = times[a-1]
        ax = fig.add_subplot(2,2,a, projection='3d')
        newleaves = timeslice(tree2,time)
        nodslice = []
        for k in tree2.Objects: ## iterate over objects in tree
            if k.x < time and k.traits['clone'] != 'omega':

                g = k.traits['clone']
                x = k.traits['location1']
                y = k.traits['location2']
                if  k.parent.traits.has_key('location1'):
                    xp = k.parent.traits['location1']
                else:
                    xp  = x
                if  k.parent.traits.has_key('location2'):
                    yp = k.parent.traits['location2']
                else:
                    yp = y

                if x==None: ## matplotlib won't plot Nones, like root
                    x=0.0
                if xp==None:
                    xp=x
                z = k.x
                zp = k.parent.x
                if z == None:
                    z = 0.0
                if zp == None:
                    zp = z

                if k.traits['clone'] != 'nan':
                    if k.traits.has_key('clone'):
                        c = colors3[k.traits['clone']]
                    else: 
                        c = 'silver' 

                nn = {'xcoord':x,'ycoord':y,'clone':g,'pxcoord':xp,'pycoord':yp, 'px': k.parent.x,"x":k.x} 
                nodslice.append(nn)

                ax.plot([xp,x],[yp,y],[zp,z],lw=branchWidth,color=c,ls='-',zorder=9)


        for leaf in newleaves:
            if leaf['x'] == time:
                s = 45
                x = leaf['xcoord']
                y = leaf['ycoord']
                xp = leaf['pxcoord']
                yp = leaf['pycoord']
                z = leaf['x']
                zp = leaf['px']
                if z == None:
                    z = 0.0
                if zp == None:
                    zp = z
                if leaf['clone'] != 'omega':
                    if leaf['clone'] != 'nan' and leaf.has_key('clone'):
                        c = colors3[leaf['clone']]
                    else: 
                        c = 'silver'


                    ax.scatter(x,y,z,s=s,facecolor = c, edgecolor = 'k',zorder = 10)
                    ax.plot([xp,x],[yp,y],[zp,z], lw=branchWidth,color = c, ls='-',zorder = 9)
  
        ax.set_xlabel('X coordinate (mm)')
        ax.set_ylabel('Y coordiante (mm)')
        ax.set_xlim(-17,17)
        ax.set_ylim(-17,17)
        ax.set_zlim(0,0.08)
        ax.set_title('%s of Total Distance' % timep[a-1])
        a += 1
han_list = []

for key in colors3:
    marker = mlines.Line2D(range(1), range(1), color = colors3[key], marker='o', markerfacecolor = colors3[key], label = key, markeredgecolor='k',markersize = 8)
    han_list.append(marker)

ax.legend(handles = han_list, markerfirst = True, title = 'Clone', bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.savefig('figures/3dspace_timeslice.png')
plt.show()

# %% [markdown]
# ## Contour plots for time slices of .trees file

# %% [markdown]
# Using samogitia.py parser w/ added tslice analysis to find x,y coordinates of all trees in .trees file

# %%
run samogitia.py -b 500700 -t alleles_spatial_clone_5.trees -a tslice treeLength -ti 0.02 -nc -o samogitiat25.out.txt
# Out:
# [===============               ]   49%  trees:  4995  elapsed: 17.36m  ETA:  0.29h (2.1e-01 s/tree)
# Done!

# %%
run samogitia.py -b 500700 -t alleles_spatial_clone_5.trees -a tslice treeLength -ti 0.04 -nc -o samogitiat50.out.txt
# Out:
# [===============               ]   49%  trees:  4995  elapsed: 17.31m  ETA:  0.29h (2.1e-01 s/tree)
# Done!

# %%
run samogitia.py -b 500700 -t alleles_spatial_clone_5.trees -a tslice treeLength -ti 0.06 -nc -o samogitiat75.out.txt
# Out:
# [===============               ]   49%  trees:  4995  elapsed: 17.47m  ETA:  0.29h (2.1e-01 s/tree)
# Done!

# %%
run samogitia.py -b 500700 -t alleles_spatial_clone_5.trees -a tslice treeLength -ti 0.08 -nc -o samogitiat100.out.txt
# Out:
# [===============               ]   49%  trees:  4995  elapsed: 17.88m  ETA:  0.30h (2.1e-01 s/tree)
# Done!

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Contour plots:

# %%
colors3 = {'beta':'lightgreen','gamma': 'gold', 'alpha': 'darkturquoise', 'epsilon':'salmon', 'zeta': 'orange', 'eta':'magenta','delta':
          'deepskyblue','mu':'green'}
branchWidth = 2
fig,ax = plt.subplots(2,2,figsize=(15,15),sharex='col', sharey='row')
timep = ['25%', '50%', '75%','100%']
counter = 0
outfiles = ['samogitiat25.out.txt', 'samogitiat50.out.txt','samogitiat75.out.txt','samogitiat100.out.txt']
for i in [0,1]:
    for j in [0,1]:
        treesData = pd.read_csv(outfiles[counter], sep = '\t') #t is 25% of mcc tree
        convi = np.flatnonzero(treesData['treeLength'] < 4)[0] #use tree length as measure of convergence
        converged = treesData.iloc[convi:,:]
        for key in colors3:
            trees_clone = converged[converged['sliceg'] == key]
            x = trees_clone['tsliceX'].values
            y = trees_clone['tsliceY'].values
            c = colors3[key]
            par = sns.light_palette(c,as_cmap = True, input = 'xcdc')
            ax[i,j] = sns.kdeplot(x,y, cmap = par, ax = ax[i,j])
            ax[1,j].set_xlabel('X coordinate (mm)')
            ax[i,0].set_ylabel('Y coordiante (mm)')
            ax[i,j].set_xlim(-20,20)
            ax[i,j].set_ylim(-20,20)
            ax[i,j].set_title('%s of Total Distance of MCC tree' % timep[counter])
        counter += 1
            
han_list = []
for key in colors3:
    marker = mlines.Line2D(range(1), range(1), color = colors3[key], label = key, markeredgecolor='k',markersize = 8)
    han_list.append(marker)

ax[1,1].legend(handles = han_list, markerfirst = True, title = 'Clone', bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.savefig('figures/contour_timeslice.png')

# %%
colors3 = {'beta':'lightgreen','gamma': 'gold', 'alpha': 'darkturquoise', 'epsilon':'salmon', 'zeta': 'orange', 'eta':'magenta','delta':
          'deepskyblue','mu':'green'}
branchWidth = 2
fig,ax = plt.subplots(2,2,figsize=(15,15),sharex='col', sharey='row')
timep = ['25%', '50%', '75%','100%']
counter = 0
outfiles = ['samogitiat25.out.txt', 'samogitiat50.out.txt','samogitiat75.out.txt','samogitiat100.out.txt']
for i in [0,1]:
    for j in [0,1]:
        treesData = pd.read_csv(outfiles[counter], sep = '\t') #t is 25% of mcc tree
        convi = np.flatnonzero(treesData['treeLength'] < 4)[0] #use tree length as measure of convergence
        converged = treesData.iloc[convi:,:]
        for key in colors3:
            trees_clone = converged[converged['sliceg'] == key]
            x = trees_clone['tsliceX'].values
            y = trees_clone['tsliceY'].values
            c = colors3[key]
            par = sns.light_palette(c,as_cmap = True, input = 'xcdc')
            ax[i,j] = sns.kdeplot(x,y, cmap = par, ax = ax[i,j])
            
        time = times[counter]
        newleaves = timeslice(tree2,time)
        nodslice = []
        for k in tree2.Objects: ## iterate over objects in tree
            if k.x < time and k.traits['clone'] != 'omega':

                g = k.traits['clone']
                x = k.traits['location1']
                y = k.traits['location2']
                if  k.parent.traits.has_key('location1'):
                    xp = k.parent.traits['location1']
                else:
                    xp  = x
                if  k.parent.traits.has_key('location2'):
                    yp = k.parent.traits['location2']
                else:
                    yp = y

                if x==None: ## matplotlib won't plot Nones, like root
                    x=0.0
                if xp==None:
                    xp=x

                if k.traits['clone'] != 'nan':
                    if k.traits.has_key('clone'):
                        c = colors3[k.traits['clone']]
                    else: 
                        c = 'silver' 

                nn = {'xcoord':x,'ycoord':y,'clone':g,'pxcoord':xp,'pycoord':yp, 'px': k.parent.x,"x":k.x} 
                nodslice.append(nn)

                ax[i,j].plot([xp,x],[yp,y],lw=branchWidth,color=c,ls='-',zorder=9)


        for leaf in newleaves:
            if leaf['x'] == time:
                s = 45
                x = leaf['xcoord']
                y = leaf['ycoord']
                xp = leaf['pxcoord']
                yp = leaf['pycoord']
                if leaf['clone'] != 'omega':
                    if leaf['clone'] != 'nan' and leaf.has_key('clone'):
                        c = colors3[leaf['clone']]
                    else: 
                        c = 'silver'


                    ax[i,j].scatter(x,y,s=s,facecolor = c, edgecolor = 'k',zorder = 10)
                    ax[i,j].plot([xp,x],[yp,y], lw=branchWidth,color = c, ls='-',zorder = 9)
  
            ax[1,j].set_xlabel('X coordinate (mm)')
            ax[i,0].set_ylabel('Y coordiante (mm)')
            ax[i,j].set_xlim(-20,20)
            ax[i,j].set_ylim(-20,20)
            ax[i,j].set_title('%s of Total Distance of MCC tree' % timep[counter])
        counter += 1
            
han_list = []
for key in colors3:
    marker = mlines.Line2D(range(1), range(1), color = colors3[key],label = key)
    han_list.append(marker)

ax[1,1].legend(handles = han_list, markerfirst = True, title = 'Clone', bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.savefig('figures/contour_timeslice_mcc.png')

# %% [markdown]
# tree2 = bt.loadNexus('alleles_spatial_clone_55.mcc', absoluteTime=False) #tree with locations + clones as infered trait
# times = [tree2.treeHeight * x / 4 for x in range(1,5)]
# colors3 = {'beta':'lightgreen','gamma': 'gold', 'alpha': 'darkturquoise', 'epsilon':'salmon', 'zeta': 'orange', 'eta':'magenta','delta':
#           'deepskyblue','mu':'green'}
# counter = 0
# outfiles = ['samogitiat25.out.txt', 'samogitiat50.out.txt','samogitiat75.out.txt','samogitiat100.out.txt']
# branchWidth = 2
# timep = ['25%', '50%', '75%','100%']
# times = [0.02,0.04,0.06,0.08]
#
# fig = plt.figure(figsize=(15,15))
# #ax = fig.add_subplot(221, projection='3d')
# #fig,ax = plt.subplots(2,2, projection='3d',figsize=(15,15), sharex='col', sharey='row')
#
#
# for i in [0,1]:
#     for j in [0,1]:
#         time = times[counter]
#         ax = fig.add_subplot(2,2,counter+1, projection='3d')
#         treesData = pd.read_csv(outfiles[counter], sep = '\t') #t is 25% of mcc tree
#         convi = np.flatnonzero(treesData['treeLength'] < 4)[0] #use tree length as measure of convergence
#         converged = treesData.iloc[convi:,:]
#         for key in colors3:
#             trees_clone = converged[converged['sliceg'] == key]
#             x = trees_clone['tsliceX'].values
#             y = trees_clone['tsliceY'].values
#             c = colors3[key]
#             par = sns.light_palette(c,as_cmap = True, input = 'xcdc')
#             ax = sns.kdeplot(x,y,time, cmap = par, ax = ax)
#         newleaves = timeslice(tree2,time)
#         nodslice = []
#         for k in tree2.Objects: ## iterate over objects in tree
#             if k.x < time and k.traits['clone'] != 'omega':
#
#                 g = k.traits['clone']
#                 x = k.traits['location1']
#                 y = k.traits['location2']
#                 if  k.parent.traits.has_key('location1'):
#                     xp = k.parent.traits['location1']
#                 else:
#                     xp  = x
#                 if  k.parent.traits.has_key('location2'):
#                     yp = k.parent.traits['location2']
#                 else:
#                     yp = y
#
#                 if x==None: ## matplotlib won't plot Nones, like root
#                     x=0.0
#                 if xp==None:
#                     xp=x
#                 z = k.x
#                 zp = k.parent.x
#                 if z == None:
#                     z = 0.0
#                 if zp == None:
#                     zp = z
#
#                 if k.traits['clone'] != 'nan':
#                     if k.traits.has_key('clone'):
#                         c = colors3[k.traits['clone']]
#                     else:
#                         c = 'silver'
#
#                 nn = {'xcoord':x,'ycoord':y,'clone':g,'pxcoord':xp,'pycoord':yp, 'px': k.parent.x,"x":k.x}
#                 nodslice.append(nn)
#
#                 ax.plot([xp,x],[yp,y],[zp,z],lw=branchWidth,color=c,ls='-',zorder=9)
#
#
#         for leaf in newleaves:
#             if leaf['x'] == time:
#                 s = 45
#                 x = leaf['xcoord']
#                 y = leaf['ycoord']
#                 xp = leaf['pxcoord']
#                 yp = leaf['pycoord']
#                 z = leaf['x']
#                 zp = leaf['px']
#                 if z == None:
#                     z = 0.0
#                 if zp == None:
#                     zp = z
#                 if leaf['clone'] != 'omega':
#                     if leaf['clone'] != 'nan' and leaf.has_key('clone'):
#                         c = colors3[leaf['clone']]
#                     else:
#                         c = 'silver'
#
#
#                     ax.scatter(x,y,z,s=s,facecolor = c, edgecolor = 'k',zorder = 10)
#                     ax.plot([xp,x],[yp,y],[zp,z], lw=branchWidth,color = c, ls='-',zorder = 9)
#
#         ax.set_xlabel('X coordinate (mm)')
#         ax.set_ylabel('Y coordiante (mm)')
#         ax.set_xlim(-17,17)
#         ax.set_ylim(-17,17)
#         ax.set_zlim(0,0.08)
#         ax.set_title('%s of Total Distance' % timep[counter])
#         counter += 1
# han_list = []
#
# for key in colors3:
#     marker = mlines.Line2D(range(1), range(1), color = colors3[key], marker='o', markerfacecolor = colors3[key], label = key, markeredgecolor='k',markersize = 8)
#     han_list.append(marker)
#
# ax.legend(handles = han_list, markerfirst = True, title = 'Clone', bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
# plt.savefig('figures/3dspace_timeslice.png')
# plt.show()

# %%
treesData = pd.read_csv('samogitiat25.out.txt', sep = '\t') #t is 25% of mcc tree
convi = np.flatnonzero(treesData['treeLength'] < 4)[0] #use tree length as measure of convergence
converged = treesData.iloc[convi:,:]
for key in colors3:
    trees_clone = converged[converged['sliceg'] == key]
    x = trees_clone['tsliceX'].values
    y = trees_clone['tsliceY'].values
    c = colors3[key]
    par = sns.light_palette(c,as_cmap = True, input = 'xcdc')
    ax = sns.kdeplot(x,y, cmap = par)

ax.set_xlabel('X coordinate (mm)')
ax.set_ylabel('Y coordiante (mm)')
ax.set_xlim(-17,17)
ax.set_ylim(-17,17)
ax.set_title('25% of Total Distance of MCC tree')
ax.legend(handles = han_list, markerfirst = True, title = 'Clone')

plt.savefig('figures/contour_timeslice_25.png')

# %%
treesData = pd.read_csv('samogitiat50.out.txt', sep = '\t')
treesData = treesData[treesData['treeLength']<4]
for key in colors3:
    trees_clone = treesData[treesData['sliceg'] == key]
    x = trees_clone['tsliceX'].values
    y = trees_clone['tsliceY'].values
    c = colors3[key]
    par = sns.light_palette(c,as_cmap = True, input = 'xcdc')
    ax = sns.kdeplot(x,y, cmap = par)
    
ax.set_xlabel('X coordinate (mm)')
ax.set_ylabel('Y coordiante (mm)')
ax.set_xlim(-17,17)
ax.set_ylim(-17,17)
ax.set_title('50% of Total Distance of MCC tree')
ax.legend(handles = han_list, markerfirst = True, title = 'Clone')
plt.savefig('figures/contour_timeslice50_.png')

# %%
treesData = pd.read_csv("samogitiat75.out.txt", sep = '\t')
treesData = treesData[treesData['treeLength']<4]
for key in colors3:
    trees_clone = treesData[treesData['sliceg'] == key]
    x = trees_clone['tsliceX'].values
    y = trees_clone['tsliceY'].values
    c = colors3[key]
    par = sns.light_palette(c,as_cmap = True, input = 'xcdc')
    ax = sns.kdeplot(x,y, cmap = par)
    
ax.set_xlabel('X coordinate (mm)')
ax.set_ylabel('Y coordiante (mm)')
ax.set_xlim(-17,17)
ax.set_ylim(-17,17)
ax.set_title('75% of Total Distance of MCC tree')
ax.legend(handles = han_list, markerfirst = True, title = 'Clone')
plt.savefig('figures/contour_timeslice75_.png')

# %%
treesData = pd.read_csv("samogitiat100.out.txt", sep = '\t')
treesData = treesData[treesData['treeLength']<4]
for key in colors3:
    trees_clone = treesData[treesData['sliceg'] == key]
    x = trees_clone['tsliceX'].values
    y = trees_clone['tsliceY'].values
    c = colors3[key]
    par = sns.light_palette(c,as_cmap = True, input = 'xcdc')
    ax = sns.kdeplot(x,y, cmap = par)

ax.set_xlabel('X coordinate (mm)')
ax.set_ylabel('Y coordiante (mm)')
ax.set_xlim(-17,17)
ax.set_ylim(-17,17)
ax.set_title('100% of Total Distance of MCC tree')
ax.legend(handles = han_list, markerfirst = True, title = 'Clone')
plt.savefig('figures/contour_timeslice100_.png')

# %% [markdown]
# ## Smoothing branches in 3D representation

# %%
run samogitia.py -b 500700 -t alleles_spatial_clone_5.trees -a lsmooth -nc -gl 0.1 -j 100 -o samogitia_smooth.out.txt
# Out:
# [===============               ]   49%  trees:  4995  elapsed:  1.09m  ETA:  0.02h (1.3e-02 s/tree)
# Done!

# %%
data = pd.read_csv("samogitia_smooth.out.txt",sep = '\t')

# %%
xdata = data.filter(regex='^x.', axis=1)
ydata = data.filter(regex='y.', axis=1)
gdata = data.filter(regex='^g.', axis=1)

# %%
xaverage = xdata.mean(axis = 0)
yaverage = ydata.mean(axis = 0)
gmode = gdata.mode(axis = 0)
gmode = gmode.iloc[0] # could use group names from each tree

# %%
from mpl_toolkits.mplot3d import Axes3D
tree2 = bt.loadNexus('alleles_spatial_clone_55.mcc', absoluteTime=False) #tree with locations + clones as infered trait
colors3 = {'beta':'lightgreen','gamma': 'gold', 'alpha': 'darkturquoise', 'epsilon':'salmon', 'zeta': 'orange', 'eta':'magenta','delta':
          'deepskyblue','mu':'green'}
inc = glength/len(tree2.leaves)
grid = np.arange(0,glength,inc)

fig = plt.figure(figsize=(16,16))
ax = fig.add_subplot(111, projection='3d')

branchWidth=2 ## default branch width
tipx = []
tipy = []
tipz = []
tipg = []

import operator
sorted_l = sorted(tree2.leaves, key=operator.attrgetter('name')) 
for l in sorted_l:
    
    x = l.traits['location1']
    y = l.traits['location2']
    z = l.x
    g = l.traits['clone']
    tipx.append(x)
    tipy.append(y)
    tipz.append(z)
    tipg.append(g)
    
    #cur_node = l
    #zval = []
   # gval = []
    #wile cur_node != None:
        #z= cur_node.x
        #if z == None:
            #z = 0.0
        #zval.append(z)
        #gval.append(cur_node.traits['clone']
        #cur_node = cur_node.parent
                    
    #zvals.append(zval)
    #gvals.append(gval)
            
    
    if l.traits['clone'] != 'omega':
        if l.traits['clone'] != 'nan':
            c = colors3[l.traits['clone']] if l.traits.has_key('clone') else cmap(1.0)[0]
        else:
            c = 'silver'
        s = 50
        ax.scatter(x, y, z, zdir='z', s=s, c=c, depthshade=True,zorder = 10,edgecolor = 'k')

for branch in range(len(tree2.leaves)):
    bstring= '._%s'%(str(branch))
    xbranch_vals = xaverage.filter(regex = bstring)
    ybranch_vals = yaverage.filter(regex = bstring)
    gvals = gmode.filter(regex = bstring)
    for point in range(1,len(grid)):
        x = xbranch_vals[point]
        xp = xbranch_vals[point- 1]
        y = ybranch_vals[point]
        yp = ybranch_vals[point-1]
        z = grid[point]
        zp = grid[point-1]
        #gindex = min(range(len(zv)), key=lambda i: abs(zv[i]-grid[point])) ##take group of node closest to grid point
        group = gvals[point]
        if group != 'omega':
            if group != 'nan':
                c = colors3[group]
            else: 
                c = 'silver'
        if z > tree2.treeHeight:
            x = tipx[branch]
            y = tipy[branch]
            z = tipz[branch]
            if zp > tree2.treeHeight:
                zp = z
                xp = x
                yp = y
        ax.plot([xp,x],[yp,y],[zp,z],lw=branchWidth,color=c,ls='-',zorder=9)
        

han_list = []

for key in colors3:
    marker = mlines.Line2D(range(1), range(1), color = colors3[key], marker='o', markerfacecolor = colors3[key], label = key, markeredgecolor='k',markersize = 8)
    han_list.append(marker)

plt.legend(handles = han_list,markerfirst = True,title = 'Clone')
ax.set_xlabel('X coordinate (mm)')
ax.set_ylabel('Y coordiante (mm)')
ax.set_zticks([])


plt.savefig('figures/3dspaceTree_smooth.png')
plt.show()

# %% [markdown]
# ## Local Branching Index
# Metric developed by Neher, Russel and Shraiman approximation for fitness

# %%
import operator
import copy
import numpy as np
def calc_LBI(tree, attr = 'lb', tau=0.0005, transform = lambda x:x):
    '''.
    traverses the tree in postorder and preorder to calculate the
    up and downstream tree length exponentially weighted by distance.
    then adds them as LBI
    tree -- dendropy tree for whose node the LBI is being computed
    attr	 -- the attribute name used to store the result

    '''
    newtree=copy.deepcopy(tree)
    newtree.postorder_node = sorted(newtree.Objects, key=operator.attrgetter('height'), reverse = True)
    newtree.preorder_internal_node = sorted(newtree.nodes, key = operator.attrgetter('height'), reverse = False)

    # traverse the tree in postorder (children first) to calculate msg to parents
    for node in newtree.postorder_node:
        node.down_polarizer = 0
        node.up_polarizer = 0
        if isinstance(node,bt.node) or node.branchType=='node':
            for child in node.children:
                node.up_polarizer += child.up_polarizer
        bl =  node.length/tau
        node.up_polarizer *= np.exp(-bl)
        node.up_polarizer += tau*(1-np.exp(-bl))

    # traverse the tree in preorder (parents first) to calculate msg to children
    for node in newtree.preorder_internal_node:
        for child1 in node.children:
            child1.down_polarizer = node.down_polarizer
        for child2 in node.children:
            if child1!=child2:
                child1.down_polarizer += child2.up_polarizer

        bl =  child1.length/tau
        child1.down_polarizer *= np.exp(-bl)
        child1.down_polarizer += tau*(1-np.exp(-bl))

    # go over all nodes and calculate the LBI (can be done in any order)
    for node in newtree.postorder_node:
        tmp_LBI = node.down_polarizer
        if isinstance(node,bt.node) or node.branchType=='node':
            for child in node.children:
                tmp_LBI += child.up_polarizer
    #node.__setattr__(attr, transform(tmp_LBI))
        setattr(node, attr, transform(tmp_LBI))
    return newtree

# %%
import baltic as bt
tree2 = bt.loadNexus('alleles_spatial_clone_55.mcc', absoluteTime=False) #tree with locations + clones as infered traits
ttree = calc_LBI(tree2)
colors2 = {'beta':'lightgreen','gamma': 'gold', 'alpha': 'darkturquoise', 'epsilon':'salmon', 'zeta': 'orange', 'eta':'magenta','delta':
          'deepskyblue','mu':'green','omega':'k'}

# %%
LBIlist = []
for k in ttree.leaves:
    LBIlist.append(k.lb)
    if k.lb < 0.0005:
        print k.name

maxlb = max(LBIlist)
minlb = min(LBIlist)
spec = maxlb - minlb
print maxlb
# Out:
# C78
# D25|epsilon|-1.60|10.66
# 0.00127236129657

# %%
fig1,ax = plt.subplots(figsize=(10,20),facecolor='w')
#ax = fig.add_subplot(3, 1, 1)
branchWdith = 2

cmap=mpl.cm.inferno ## colors! https://github.com/blab/wiki/wiki/Colors

for k in ttree.Objects: ## iterate over objects in tree
    branchWidth = 2
    x=k.x ## or from x position determined earlier
#     x=k.absoluteTime ## or use absolute time instead
    y=k.y ## get y position from .drawTree that was run earlier, but could be anything else
    
    xp=k.parent.x ## get x position of current object's parent
#     xp=k.parent.absoluteTime ## get x position of current object's parent
    if x==None: ## matplotlib won't plot Nones, like root
        x=0.0
    if xp==None:
        xp=x
    #if (isinstance(k, bt.leaf) or k.branchType=='leaf') and len(k.name.split('|')) > 1:
    #if isinstance(k, bt.leaf) and len(k.name.split('|')) > 1:
        #c = colors[k.name.split('|')[-3]]
    #else:
        #c='dimgray' ## colour can be fixed
    if k.traits['clone'] != 'nan':
        c = colors2[k.traits['clone']] if k.traits.has_key('clone') else cmap(1.0)[0]
    else: c = 'silver'
#     c=cmap(k.height/ll.treeHeight) ## or be a function of something else
#     c=[cmap(k.traits['host.prob']) if k.traits.has_key('host.prob') else cmap(1.0)][0]
#     c=['indianred' if k.traits['PB1']=='V' else 'steelblue'][0] ## can be discrete too
    
    if isinstance(k,bt.leaf) or k.branchType=='leaf': ## if leaf...
        #x=decimalDate(k.name.split('_')[-1],variable=True) ## get x position from name
        lb = k.lb
        cl = cmap(lb / (maxlb - .0005))
        s=20 ## tip size can be fixed
        #s=50-30*k.height/tree2.treeHeight
        
        ax.scatter(x,y,s=s,facecolor=cl,edgecolor='none',zorder=11) ## plot circle for every tip
        ax.scatter(x,y,s=s+0.8*s,facecolor='k',edgecolor='none',zorder=10) ## plot black circle underneath
    elif isinstance(k,bt.node) or k.branchType=='node': ## if node...
        #ax.plot([x,x],[k.children[-1].y,k.children[0].y],lw=branchWidth,color=c,ls='-',zorder=9)
        ax.plot([x,x],[k.children[-1].y,k.children[0].y],lw=branchWidth, color= c ,ls='-',zorder=9)
        
    #ax.plot([xp,x],[y,y],lw=branchWidth,color=c,ls='-',zorder=9)
    ax.plot([xp,x],[y,y],lw=branchWidth,color= c ,ls='-',zorder=9)
    
       
ax.set_ylim(-5,tree2.ySpan+5)
han_list = []

for key in colors2:
    marker = mlines.Line2D(range(1), range(1), color = colors2[key], marker='o', markerfacecolor = colors2[key], label = key, markeredgecolor='k',markersize = 8)
    han_list.append(marker)

plt.legend(handles = han_list,markerfirst = True,title = 'Clone')
plt.savefig('figures/rootedTree.png')
plt.show()

# %%
tree2 = bt.loadNexus('alleles_spatial_clone_55.mcc', absoluteTime=False) #tree with locations + clones as infered traits
tree2.uncollapseSubtree() ## uncollapse
tree2.drawUnrooted() ## draw tree as unrooted
ttree = calc_LBI(tree2)

fig,ax = plt.subplots(figsize=(10,10),facecolor='w')


for k in ttree.Objects: ## iterate over objects in tree
    x=k.x ## or from x position determined earlier
    y=k.y ## get y position from .drawTree that was run earlier, but could be anything else
    
    xp=k.parent.x ## get x position of current object's parent
    yp=k.parent.y
    
    if x==None: ## matplotlib won't plot Nones, like root
        x=0.0
    if xp==None:
        xp=x

    if k.traits['clone'] != 'nan':
        c = colors2[k.traits['clone']] if k.traits.has_key('clone') else cmap(1.0)[0]
    else: c = 'silver' 
    #cmap=[mpl.cm.Reds if k.traits['type']=='HongKong' else mpl.cm.Blues][0] ## pick colour map based on trait
    #c=cmap(k.height/mtt.treeHeight) ## colour with colour map based on height of branch
    if k.branchType=='leaf': ## if leaf...
        #s=30 ## tip size can be fixed
        s=30*k.height/tree2.treeHeight
        lb = k.lb
        cl = cmap(lb / maxlb + 0.1)       

        ax.scatter(x,y,s=s,facecolor=cl,edgecolor='none',zorder=11) ## plot circle for every tip
        ax.scatter(x,y,s=s*2,facecolor='k',edgecolor='none',zorder=10) ## plot black circle underneath
    
    ax.plot([xp,x],[yp,y],lw=branchWidth,color=c,ls='-',zorder=9)

ax.spines['top'].set_visible(False) ## no axes
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

ax.tick_params(axis='x',size=0) ## no labels
ax.tick_params(axis='y',size=0)
ax.set_xticklabels([])
ax.set_yticklabels([])
plt.savefig('figures/unrootedTree.png')
